# %% [markdown]
# ## HOW TO  HANDEL  NULL DATA

# %% [markdown]
# ### * MISSING VALUES OR NULL DATA HANDLING.
#
# CAN BE REPRESENTED IN DIFFERENT WAYS("-", "NAN", " ")
#
# 1. BY TAKING AVERAGE VALUE AND REPLACING WITH NULL DATA.
#
#
# 2. BY DROPING NULL VALUES FROM DATAFRAME

# %%
# IMPORT REQUIRED  LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
# IMPORT "CSV" FILE.

# %%
## Cancer survivaldata
# Importing experimenting Data

DATA = pd.read_csv("/home/saiviswas/Downloads/dataset/data.csv")

# %%
#  Reading data 

DATA
# Out:
#      Unnamed: 0  inst  time  status  age  sex  ph.ecog  ph.karno  pat.karno  \
# 0             1   3.0   306       2   74    1      1.0      90.0      100.0
# 1             2   3.0   455       2   68    1      0.0      90.0       90.0
# 2             3   3.0  1010       1   56    1      0.0      90.0       90.0
# 3             4   5.0   210       2   57    1      1.0      90.0       60.0
# 4             5   1.0   883       2   60    1      0.0     100.0       90.0
# ..          ...   ...   ...     ...  ...  ...      ...       ...        ...
# 223         224   1.0   188       1   77    1      1.0      80.0       60.0
# 224         225  13.0   191       1   39    1      0.0      90.0       90.0
# 225         226  32.0   105       1   75    2      2.0      60.0       70.0
# 226         227   6.0   174       1   66    1      1.0      90.0      100.0
# 227         228  22.0   177       1   58    2      1.0      80.0       90.0
#
#      meal.cal  wt.loss
# 0      1175.0      NaN
# ...

# %%
# FINDING THE SHAPE OF THE DATAFRAME

DATA.shape
# Out:
# (228, 11)

# %%
# MAKING COPY OF DATA TO DROP NULL VALUES FROM DATAFRAME. 

DUPLICATE_DATA  = DATA

# %%
# IN ABOVE DATAFRAME WE CAN SEE "NaN" VALUES IN THE DATA.

# %%
#  RENAMING THE ROW NAMES

DATA = DATA.rename(columns={"ph.ecog":"ph_ecog",
                            "ph.karno":"ph_karno",
                            "pat.karno":"pat_karno",
                            "meal.cal":"meal_cal",
                            "wt.loss":"wt_loss"
})

# %%
# DATA AFTER REPLACING THE ROW 

DATA[0:0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, inst, time, status, age, sex, ph_ecog, ph_karno, pat_karno, meal_cal, wt_loss]
# Index: []

# %% [markdown]
# ### WAYS TO OPERATE WITH NULL VALUES
#
# "isnull()" : TO GENERATE A BOOLEAN DATA INDICATING MISSING VALUES.
#
# "notnull()": OPPOSITE OF "isnull()".
#
# "dropna()" : RETURN A FILTERED DATA ("DROPING ALL NULL VALUES").
#
# "fillna()" : FILLING THE DATA WITH MISSING VALUES.

# %%
# FIND THE  NULL DATA VALUES IN DATAFRAME

# DATA  WILL  BE REPRESENTED IN BOOLEAN FORMATE WHETHER DATA IS ("TRUE" OR "FALSE").

# TRUE INDICATES THE NULL VALUE.

DATA.isnull()
# Out:
#      Unnamed: 0   inst   time  status    age    sex  ph_ecog  ph_karno  \
# 0         False  False  False   False  False  False    False     False
# 1         False  False  False   False  False  False    False     False
# 2         False  False  False   False  False  False    False     False
# 3         False  False  False   False  False  False    False     False
# 4         False  False  False   False  False  False    False     False
# ..          ...    ...    ...     ...    ...    ...      ...       ...
# 223       False  False  False   False  False  False    False     False
# 224       False  False  False   False  False  False    False     False
# 225       False  False  False   False  False  False    False     False
# 226       False  False  False   False  False  False    False     False
# 227       False  False  False   False  False  False    False     False
#
#      pat_karno  meal_cal  wt_loss
# 0        False     False     True
# 1        False     False    False
# ...

# %%
# FINDING TOTAL SUM() NULL VALUES.

DATA.isnull().sum()
# Out:
# Unnamed: 0     0
# inst           1
# time           0
# status         0
# age            0
# sex            0
# ph_ecog        1
# ph_karno       1
# pat_karno      3
# meal_cal      47
# wt_loss       14
# dtype: int64

# %% [markdown]
# ## MEAN VALUES

# %%
# THE "MEAN VALUE" INDICATES AVERAGE VALUE.

#TO FIND THE MEAN DATA, ADD  TOGETHER ALL OF YOUR  VALUES AND DIVIDE BY THE NUMBER OF ADDENDS. 

#FINDING THE MEAN VALUES

DATA_mean = DATA.mean()

# %%
# FINDING THE MEAN VALUES 

DATA_mean
# Out:
# Unnamed: 0    114.500000
# inst           11.088106
# time          305.232456
# status          1.723684
# age            62.447368
# sex             1.394737
# ph_ecog         0.951542
# ph_karno       81.938326
# pat_karno      79.955556
# meal_cal      928.779006
# wt_loss         9.831776
# dtype: float64

# %%
# FILLING THE NULL VALUES WITH THE MEAN 

DATA.fillna(DATA_mean,inplace= True)

# %%
# AFTER FILLING NULL VALUES

DATA
# Out:
#      Unnamed: 0  inst  time  status  age  sex  ph_ecog  ph_karno  pat_karno  \
# 0             1   3.0   306       2   74    1      1.0      90.0      100.0
# 1             2   3.0   455       2   68    1      0.0      90.0       90.0
# 2             3   3.0  1010       1   56    1      0.0      90.0       90.0
# 3             4   5.0   210       2   57    1      1.0      90.0       60.0
# 4             5   1.0   883       2   60    1      0.0     100.0       90.0
# ..          ...   ...   ...     ...  ...  ...      ...       ...        ...
# 223         224   1.0   188       1   77    1      1.0      80.0       60.0
# 224         225  13.0   191       1   39    1      0.0      90.0       90.0
# 225         226  32.0   105       1   75    2      2.0      60.0       70.0
# 226         227   6.0   174       1   66    1      1.0      90.0      100.0
# 227         228  22.0   177       1   58    2      1.0      80.0       90.0
#
#         meal_cal    wt_loss
# ...

# %%
#  SO ALL  THE NULL NULL VALUES  ARE REPLACED WITH  MEAN VALUES

# %%
DATA.isnull().sum()
# Out:
# Unnamed: 0    0
# inst          0
# time          0
# status        0
# age           0
# sex           0
# ph_ecog       0
# ph_karno      0
# pat_karno     0
# meal_cal      0
# wt_loss       0
# dtype: int64

# %% [markdown]
# ### DROPING NULL VALUE FROM DATAFRAME

# %%
# SELECT DATAFRAME 

DUPLICATE_DATA
# Out:
#      Unnamed: 0  inst  time  status  age  sex  ph.ecog  ph.karno  pat.karno  \
# 0             1   3.0   306       2   74    1      1.0      90.0      100.0
# 1             2   3.0   455       2   68    1      0.0      90.0       90.0
# 2             3   3.0  1010       1   56    1      0.0      90.0       90.0
# 3             4   5.0   210       2   57    1      1.0      90.0       60.0
# 4             5   1.0   883       2   60    1      0.0     100.0       90.0
# ..          ...   ...   ...     ...  ...  ...      ...       ...        ...
# 223         224   1.0   188       1   77    1      1.0      80.0       60.0
# 224         225  13.0   191       1   39    1      0.0      90.0       90.0
# 225         226  32.0   105       1   75    2      2.0      60.0       70.0
# 226         227   6.0   174       1   66    1      1.0      90.0      100.0
# 227         228  22.0   177       1   58    2      1.0      80.0       90.0
#
#      meal.cal  wt.loss
# 0      1175.0      NaN
# ...

# %%
# FIND THE  NULL DATA VALUES IN DATAFRAME

# DATA  WILL  BE REPRESENTED IN BOOLEAN FORMATE WHETHER DATA IS ("TRUE" OR "FALSE").

# TRUE INDICATES THE NULL VALUE.

DUPLICATE_DATA.isnull()
# Out:
#      Unnamed: 0   inst   time  status    age    sex  ph.ecog  ph.karno  \
# 0         False  False  False   False  False  False    False     False
# 1         False  False  False   False  False  False    False     False
# 2         False  False  False   False  False  False    False     False
# 3         False  False  False   False  False  False    False     False
# 4         False  False  False   False  False  False    False     False
# ..          ...    ...    ...     ...    ...    ...      ...       ...
# 223       False  False  False   False  False  False    False     False
# 224       False  False  False   False  False  False    False     False
# 225       False  False  False   False  False  False    False     False
# 226       False  False  False   False  False  False    False     False
# 227       False  False  False   False  False  False    False     False
#
#      pat.karno  meal.cal  wt.loss
# 0        False     False     True
# 1        False     False    False
# ...

# %%
# # FINDING TOTAL SUM() NULL VALUES.

DUPLICATE_DATA.isnull().sum()
# Out:
# Unnamed: 0     0
# inst           1
# time           0
# status         0
# age            0
# sex            0
# ph.ecog        1
# ph.karno       1
# pat.karno      3
# meal.cal      47
# wt.loss       14
# dtype: int64

# %%
## FOR EXAMPLE  

# LET US CONSIDER FIRST 5 COLUMNS.

NULL_DATA = pd.DataFrame(DUPLICATE_DATA.head())

# %%
# DATAFRAME

NULL_DATA
# Out:
#    Unnamed: 0  inst  time  status  age  sex  ph.ecog  ph.karno  pat.karno  \
# 0           1   3.0   306       2   74    1      1.0      90.0      100.0
# 1           2   3.0   455       2   68    1      0.0      90.0       90.0
# 2           3   3.0  1010       1   56    1      0.0      90.0       90.0
# 3           4   5.0   210       2   57    1      1.0      90.0       60.0
# 4           5   1.0   883       2   60    1      0.0     100.0       90.0
#
#    meal.cal  wt.loss
# 0    1175.0      NaN
# 1    1225.0     15.0
# 2       NaN     15.0
# 3    1150.0     11.0
# 4       NaN      0.0

# %%
# PERFORMING "dropna()"

NULL_DATA = NULL_DATA.dropna()

# %%
# AFTER DROPING NULL VALUES. 

NULL_DATA
# Out:
#    Unnamed: 0  inst  time  status  age  sex  ph.ecog  ph.karno  pat.karno  \
# 1           2   3.0   455       2   68    1      0.0      90.0       90.0
# 3           4   5.0   210       2   57    1      1.0      90.0       60.0
#
#    meal.cal  wt.loss
# 1    1225.0     15.0
# 3    1150.0     11.0

# %% [markdown]
#                       ************************************END*******************************
